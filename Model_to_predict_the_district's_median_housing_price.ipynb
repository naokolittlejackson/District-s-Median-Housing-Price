# %% [markdown]
# <a href="https://colab.research.google.com/github/naokolittlejackson/Districts-Median-Housing-Price/blob/main/Model_to_predict_the_district's_median_housing_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Libraries

# %%
import pandas as pd

# %% [markdown]
# Read the data

# %%
housing_data = pd.read_csv('anscombe.csv')

# %% [markdown]
# View the data

# %%
housing_data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33
